# %% [markdown]
# # IS 455 - Data Visualization
# ## Programming Assignment 3 - Rashmi Chhabria

# %%
import pandas as pd
import bqplot
import numpy as np
import ipywidgets
from bqplot import pyplot as plt

# %%
building_inventory = pd.read_csv("building_inventory.csv")

# %%
building_inventory
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
building_inventory_map = building_inventory.groupby(['Congress Dist', 'Agency Name'])["Square Footage"].sum().unstack()

# %%
building_inventory_map
# Out:
# Agency Name    Appellate Court / Fifth District  \
# Congress Dist
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                      15124.0
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...

# %%
# building_inventory_map = building_inventory_map.replace(np.nan, 0)
# building_inventory_map = building_inventory_map.to_numpy()
# building_inventory_map

# %%
# a = building_inventory.loc[(building_inventory['Agency Name'] == 18 & building_inventory['Congress Dist'] == 'Department of Human Services'), ['Year Acquired']].all()
# a.all()
# building_inventory.loc[(building_inventory['Agency Name'] == 'Department of Human Services') & (building_inventory['Congress Dist'] == 18), ['Year Acquired']].values
building_inventory_by_year_1 = building_inventory.loc[(building_inventory['Agency Name'] == 'Department of Human Services') & (building_inventory['Congress Dist'] == 15), 'Year Acquired'].values

# building_inventory_by_year_1 = building_inventory_by_year_1[['Square Footage', 'Year Acquired']]
# building_inventory_by_year_1 = building_inventory_by_year_1.groupby(['Year Acquired']).sum()

# fig = plt.figure(title="Total Square Footage per Year")
# axes_options = {'x': {'label': 'Year Acquired'}, 'y': {'label': 'Square Footage'}}
# line_chart = plt.plot(x = building_inventory_by_year_1.index, y = building_inventory_by_year_1['Square Footage'], axes_options=axes_options)
# fig
building_inventory_by_year_1
fig = plt.figure(title="Total Square Footage per Year")
axes_options = {'x': {'label': 'Year Acquired'}, 'y': {'label': 'Square Footage'}}
year_criteria = (building_inventory_by_year.index.isin(building_inventory_by_year_1))
line_chart = plt.plot(x = building_inventory_by_year.index[year_criteria], y = building_inventory_by_year['Square Footage'][year_criteria], axes_options=axes_options)
fig.layout.min_width = '500px'
line_chart.stroke_width = 2.5
fig
# building_inventory_by_year['Square Footage'][year_criteria]
# Out:
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(min_width='500px'), scale_…

# %%
mySelectedLabel = ipywidgets.Label() # start with our label

# %%
def on_selected(change):
    if len(change['owner'].selected) == 1: #only 1 selected
        i, j = change['owner'].selected[0] # grab the x/y coordinates
        v = building_inventory_map.iloc[i,j] # grab data value at x/y index and mean along z
        row_val = building_inventory_map.index[i]
        col_val = building_inventory_map.columns[j]
        years = building_inventory.loc[(building_inventory['Agency Name'] == col_val) & (building_inventory['Congress Dist'] == row_val), 'Year Acquired'].values
        mySelectedLabel.value = 'Total Square Footage = ' + str(v) # set our label
#         building_inventory_by_year_1 = building_inventory.loc[(building_inventory['Agency Name'] == col_val) & (building_inventory['Congress Dist'] == row_val)]
#         building_inventory_by_year_1 = building_inventory_by_year_1[['Square Footage', 'Year Acquired']]
#         building_inventory_by_year_1 = building_inventory_by_year_1.groupby(['Year Acquired']).sum()
        year_criteria = (building_inventory_by_year.index.isin(years))
        line_chart = plt.plot(x = building_inventory_by_year.index[year_criteria], y = building_inventory_by_year['Square Footage'][year_criteria], axes_options=axes_options)

        
# fig
        # NOW ALSO: update our histogram
#         hist.sample = building_inventory_map[i,j,:]

# %%
# (1) Scales: x/y, colors
col_sc = bqplot.ColorScale(scheme = "Blues")
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()

# (2) Axis: x/y, colors
c_ax = bqplot.ColorAxis(scale = col_sc, 
                        orientation = 'vertical', 
                        side = 'right')

x_ax = bqplot.Axis(scale = x_sc, label = 'Agency Name')
y_ax = bqplot.Axis(scale = y_sc, 
                   orientation = 'vertical', label = 'Congress Dist')

# (3) Marks: heatmap
heat_map = bqplot.GridHeatMap(color = building_inventory_map,
                              scales = {'color': col_sc,
                                        'row': y_sc,
                                        'column': x_sc},
                              interactions = {'click': 'select'}, # make interactive on click of each box
                              anchor_style = {'fill':'pink'}, # to make our selection blue
                              selected_style = {'opacity': 1.0}, # make 100% opaque if box is selected
                              unselected_style = {'opacity': 0.8}) # make a little see-through if not

# (4) Link selection on heatmap to other things
heat_map.observe(on_selected, 'selected')

# (5) Paint heatmap canvas, don't display yet:
fig_heatmap = bqplot.Figure(marks = [heat_map], axes = [c_ax, y_ax, x_ax], title = 'Total Square Footage for Agency Name by Congressional Dist')

# %%
fig_heatmap.layout.min_width = '500px'

# %%
building_inventory_by_year = building_inventory[['Square Footage', 'Year Acquired']]
building_inventory_by_year = building_inventory_by_year.groupby(['Year Acquired']).sum()

# %%
year_more_than_zero = building_inventory_by_year.index > 0
building_inventory_by_year = building_inventory_by_year[year_more_than_zero]
building_inventory_by_year
# Out:
#                Square Footage
# Year Acquired
# 1753                     1200
# 1802                     4440
# 1810                     4033
# 1832                   120000
# 1837                    10302
# ...                       ...
# 2015                   305093
# 2016                   304839
# 2017                     6720
# 2018                    17160
# 2019                     1520
#
# [171 rows x 1 columns]

# %%
fig = plt.figure(title="Total Square Footage per Year")
axes_options = {'x': {'label': 'Year Acquired'}, 'y': {'label': 'Square Footage'}}
# year_criteria = (building_inventory_by_year.index.isin([1996, 1997, 1998]))
line_chart = plt.plot(x = building_inventory_by_year.index, y = building_inventory_by_year['Square Footage'], axes_options=axes_options)
fig.layout.min_width = '500px'
line_chart.stroke_width = 2.5
fig
# building_inventory_by_year['Square Footage'][year_criteria]
# Out:
# Figure(axes=[Axis(label='Year Acquired', scale=LinearScale()), Axis(label='Square Footage', orientation='verti…

# %%
# side by side figures
figures = ipywidgets.HBox([fig_heatmap, fig])

# label on top
myDashboard = ipywidgets.VBox([mySelectedLabel, figures])
myDashboard
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\miniconda3\envs\untitled\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\miniconda3\envs\untitled\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ...
